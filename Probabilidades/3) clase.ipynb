# %%
from scipy.stats import binom  # Solo esta línea es necesaria

n = 10
p = 0.7
k = 3

prob = binom.pmf(k, n, p)
print(f"Probabilidad de {k} caras: {prob:.4f}")
# Out:
# Probabilidad de 3 caras: 0.0090
