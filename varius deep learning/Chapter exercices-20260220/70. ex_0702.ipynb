# %% [markdown]
# ## Coding Exercise #0702

# %% [markdown]
# ### 1. Convolutional Neural Network (color images):

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.20.0

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.datasets.cifar10 import load_data
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### 1.1. Download the data:

# %% [markdown]
# More information about the dataset can be found [here](https://www.cs.toronto.edu/~kriz/cifar.html).

# %%
(X_train, y_train), (X_test, y_test) = load_data()
n_train_size = X_train.shape[0]

# %% [markdown]
# #### 1.2. Take a look at the dataset:

# %%
# Images already reshaped as 32x32.
# 3 Color channels.
# y is not one-hot-encoded yet.
print("Training data X shape: {}".format(X_train.shape))
print("Training data y shape: {}".format(y_train.shape))
print("\n")
print("Testing data X shape: {}".format(X_test.shape))
print("Testing data y shape: {}".format(y_test.shape))
# Out:
# Training data X shape: (50000, 32, 32, 3)
# Training data y shape: (50000, 1)
#
#
# Testing data X shape: (10000, 32, 32, 3)
# Testing data y shape: (10000, 1)

# %% [markdown]
# Visualization.

# %%
i_image= 123                                                        # Image index. You can change it at will.
a_single_image= X_train[i_image,:,:,:]
plt.imshow(a_single_image)                                          #  Display as a color image.
plt.show()

# %%
# Check for the minimum and maximum pixel value.
print("MIN : {}".format(a_single_image.min()))                 
print("MAX : {}".format(a_single_image.max()))
# Out:
# MIN : 1
# MAX : 243

# %% [markdown]
# #### 1.3. Data preprocessing:

# %%
# Scaling.
X_train = X_train/255                      
X_test = X_test/255

# %% [markdown]
# #### 1.4. Define the hyperparameters and placeholders:

# %%
#batch_size = 8
batch_size = 128   # Changed from 8 to feed the GPU properly
n_epochs  = 20
learn_rate = 0.0001

# %% [markdown]
# #### 1.5. Define the deep learning model (CNN):

# %%
"""
model = tf.keras.Sequential()
model.add(tf.keras.Input(shape=(32, 32, 3)))

# 1st Convolution layer
model.add(tf.keras.layers.Conv2D(
    filters=32, kernel_size=(7, 7),
    strides=(1, 1), padding='same',
    data_format='channels_last',
    name='conv_1', activation=None))
# 1st Pooling layer
model.add(tf.keras.layers.MaxPool2D(
    pool_size=(2, 2), name='pool_1'))
    
    """
# Out:
# "\nmodel = tf.keras.Sequential()\nmodel.add(tf.keras.Input(shape=(32, 32, 3)))\n\n# 1st Convolution layer\nmodel.add(tf.keras.layers.Conv2D(\n    filters=32, kernel_size=(7, 7),\n    strides=(1, 1), padding='same',\n    data_format='channels_last',\n    name='conv_1', activation=None))\n# 1st Pooling layer\nmodel.add(tf.keras.layers.MaxPool2D(\n    pool_size=(2, 2), name='pool_1'))\n    \n    "

# %%
model = tf.keras.Sequential()
model.add(tf.keras.Input(shape=(32, 32, 3)))

# 1st Convolution layer (Updated to match Section 1.4)
model.add(tf.keras.layers.Conv2D(
    filters=32, 
    kernel_size=(5, 5),               # Changed from (7, 7) to (5, 5)
    strides=(1, 1), 
    padding='same',                   # Preserves spatial dimensions
    data_format='channels_last',
    name='conv_1', 
    activation='relu'))               # Standard activation for Conv2D

# 1st Pooling layer (Halves the dimensions)
model.add(tf.keras.layers.MaxPool2D(
    pool_size=(2, 2),                 # Stride defaults to 2 automatically
    name='pool_1'))

# %%
# 2nd Convolution layer
model.add(tf.keras.layers.Conv2D(
    filters=64, kernel_size=(5, 5),
    strides=(1, 1), padding='same',
    name='conv_2', activation='relu'))                      # Apply the ReLu activation function. 
# 2nd Pooling layer
model.add(tf.keras.layers.MaxPool2D(
    pool_size=(2, 2), name='pool_2'))

# %%
# Flattened full layer
model.add(tf.keras.layers.Flatten())
# fully connected layer
model.add(tf.keras.layers.Dense(
    units=1024, name='fc_1',
    activation='relu'))

# %%
# Dropout layer
model.add(tf.keras.layers.Dropout(
    rate=0.5))

# %%
# Output layer
model.add(tf.keras.layers.Dense(
    units=10, name='fc_2',
    activation='softmax'))

# %% [markdown]
# #### 1.7. Define the loss function and the optimizer:

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = learn_rate),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv_1 (Conv2D)                 │ (None, 32, 32, 32)     │         2,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ pool_1 (MaxPooling2D)           │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_2 (Conv2D)                 │ (None, 16, 16, 64)     │        51,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ pool_2 (MaxPooling2D)           │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc_1 (Dense)                    │ (None, 1024)           │     4,195,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc_2 (Dense)                    │ (None, 10)             │        10,250 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,259,274 (16.25 MB)
#  Trainable params: 4,259,274 (16.25 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #### 1.8. Training and Testing:

# %%
history = model.fit(X_train, y_train, epochs=n_epochs,
                    batch_size=batch_size,
                    validation_data=(X_test, y_test),
                    shuffle=True)
# Out:
# Epoch 1/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 32s 76ms/step - accuracy: 0.3698 - loss: 1.7599 - val_accuracy: 0.4656 - val_loss: 1.4930
# Epoch 2/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 30s 77ms/step - accuracy: 0.4861 - loss: 1.4457 - val_accuracy: 0.5246 - val_loss: 1.3419
# Epoch 3/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 71ms/step - accuracy: 0.5277 - loss: 1.3253 - val_accuracy: 0.5629 - val_loss: 1.2457
# Epoch 4/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 31s 78ms/step - accuracy: 0.5613 - loss: 1.2410 - val_accuracy: 0.5862 - val_loss: 1.1783
# Epoch 5/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 31s 80ms/step - accuracy: 0.5878 - loss: 1.1719 - val_accuracy: 0.6008 - val_loss: 1.1316
# Epoch 6/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 32s 82ms/step - accuracy: 0.6080 - loss: 1.1157 - val_accuracy: 0.6125 - val_loss: 1.1036
# Epoch 7/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 74ms/step - accuracy: 0.6246 - loss: 1.0713 - val_accuracy: 0.6333 - val_loss: 1.0544
# Epoch 8/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 31s 80ms/step - accuracy: 0.6394 - loss: 1.0302 - val_accuracy: 0.6391 - val_loss: 1.0323
# Epoch 9/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 30s 76ms/step - accuracy: 0.6547 - loss: 0.9884 - val_accuracy: 0.6425 - val_loss: 1.0068
# Epoch 10/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 31s 80ms/step - accuracy: 0.6653 - loss: 0.9587 - val_accuracy: 0.6633 - val_loss: 0.9617
# Epoch 11/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 30s 77ms/step - accuracy: 0.6808 - loss: 0.9187 - val_accuracy: 0.6698 - val_loss: 0.9415
# Epoch 12/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 70ms/step - accuracy: 0.6899 - loss: 0.8912 - val_accuracy: 0.6732 - val_loss: 0.9375
# Epoch 13/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 40s 69ms/step - accuracy: 0.6985 - loss: 0.8652 - val_accuracy: 0.6735 - val_loss: 0.9198
# Epoch 14/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 41s 68ms/step - accuracy: 0.7090 - loss: 0.8438 - val_accuracy: 0.6864 - val_loss: 0.8924
# Epoch 15/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 71ms/step - accuracy: 0.7157 - loss: 0.8181 - val_accuracy: 0.6897 - val_loss: 0.8813
# Epoch 16/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 31s 79ms/step - accuracy: 0.7251 - loss: 0.7934 - val_accuracy: 0.6862 - val_loss: 0.8915
# Epoch 17/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 31s 80ms/step - accuracy: 0.7340 - loss: 0.7669 - val_accuracy: 0.6978 - val_loss: 0.8700
# Epoch 18/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 30s 77ms/step - accuracy: 0.7393 - loss: 0.7490 - val_accuracy: 0.6977 - val_loss: 0.8721
# Epoch 19/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 70ms/step - accuracy: 0.7490 - loss: 0.7272 - val_accuracy: 0.7033 - val_loss: 0.8471
# Epoch 20/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 27s 70ms/step - accuracy: 0.7579 - loss: 0.7068 - val_accuracy: 0.7068 - val_loss: 0.8416
