# %% [markdown]
# ## Coding Exercise #0701

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.20.0

# %%
import tensorflow as tf
import tensorflow.compat.v1 as tf1

# %%
# Install tensorflow_datasets.
# !pip install tensorflow_datasets
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting tensorflow_datasets
#   Using cached tensorflow_datasets-4.9.9-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: absl-py in c:\users\alere\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from tensorflow_datasets) (2.4.0)
# Requirement already satisfied: dm-tree in c:\users\alere\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from tensorflow_datasets) (0.1.9)
# Requirement already satisfied: etils>=1.9.1 in c:\users\alere\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow_datasets) (1.13.0)
# Requirement already satisfied: immutabledict in c:\users\alere\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from tensorflow_datasets) (4.3.1)
# Requirement already satisfied: numpy in c:\users\alere\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from tensorflow_datasets) (2.4.2)
# Requirement already satisfied: promise in c:\users\alere\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from tensorflow_datasets) (2.3)
# Requirement already satisfied: protobuf>=3.20 in c:\users\alere\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from tensorflow_datasets) (6.33.5)
# Requirement already satisfied: psutil in c:\users\alere\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from tensorflow_datasets) (7.1.0)
# Requirement already satisfied: pyarrow in c:\users\alere\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from tensorflow_datasets) (23.0.1)
# Requirement already satisfied: requests>=2.19.0 in c:\users\alere\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from tensorflow_datasets) (2.32.5)
# Requirement already satisfied: simple_parsing in c:\users\alere\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from tensorflow_datasets) (0.1.8)
# Requirement already satisfied: tensorflow-metadata in c:\users\alere\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from tensorflow_datasets) (1.17.3)
# Requirement already satisfied: termcolor in c:\users\alere\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from tensorflow_datasets) (3.3.0)
# Requirement already satisfied: toml in c:\users\alere\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from tensorflow_datasets) (0.10.2)
# Requirement already satisfied: tqdm in c:\users\alere\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from tensorflow_datasets) (4.67.3)
# Requirement already satisfied: wrapt in c:\users\alere\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from tensorflow_datasets) (2.1.1)
# Requirement already satisfied: einops in c:\users\alere\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow_datasets) (0.8.2)
# Requirement already satisfied: fsspec in c:\users\alere\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow_datasets) (2026.2.0)
# Requirement already satisfied: importlib_resources in c:\users\alere\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow_datasets) (6.5.2)
# Requirement already satisfied: typing_extensions in c:\users\alere\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow_datasets) (4.15.0)
# Requirement already satisfied: zipp in c:\users\alere\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow_datasets) (3.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\alere\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests>=2.19.0->tensorflow_datasets) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\alere\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests>=2.19.0->tensorflow_datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\alere\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests>=2.19.0->tensorflow_datasets) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\alere\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests>=2.19.0->tensorflow_datasets) (2025.8.3)
# Requirement already satisfied: attrs>=18.2.0 in c:\users\alere\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from dm-tree->tensorflow_datasets) (25.3.0)
# Requirement already satisfied: six in c:\users\alere\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from promise->tensorflow_datasets) (1.17.0)
# Requirement already satisfied: docstring-parser~=0.15 in c:\users\alere\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from simple_parsing->tensorflow_datasets) (0.17.0)
# Requirement already satisfied: googleapis-common-protos<2,>=1.56.4 in c:\users\alere\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from tensorflow-metadata->tensorflow_datasets) (1.72.0)
# Requirement already satisfied: colorama in c:\users\alere\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from tqdm->tensorflow_datasets) (0.4.6)
# Using cached tensorflow_datasets-4.9.9-py3-none-any.whl (5.3 MB)
# Installing collected packages: tensorflow_datasets
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: 'C:\\Users\\alere\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python313\\site-packages\\tensorflow_datasets\\datasets\\open_images_challenge2019_detection\\open_images_challenge2019_detection_dataset_builder_test.py'
# HINT: This error might have occurred since this system does not have Windows Long Path support enabled. You can find information on how to enable this at https://pip.pypa.io/warnings/enable-long-paths
#
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\alere\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# Load MNIST datasets.
import tensorflow_datasets as tfds

# %%
# Set hyperparameters: BUFFER_SIZE to shuffle data, BATCH_SIZE that is mini-batch size, and the number of training epochs.
import numpy as np
BUFFER_SIZE = 10000
BATCH_SIZE = 64
NUM_EPOCHS = 20

# %%
# Define the number of times to repeat per epoch.
#steps_per_epoch = np.ceil(60000 / BATCH_SIZE)
# Define the number of times to repeat per epoch as an integer.
steps_per_epoch = int(np.ceil(60000 / BATCH_SIZE))

# %%
# Define a function that preprocesses the input image and label.
def preprocess(item):
    image = item['image']
    label = item['label']
    image = tf.image.convert_image_dtype(image, tf.float32) 
    # Devolver directamente la imagen y la etiqueta (features, labels)
    return image, label[... , tf.newaxis]

# %%
# Define two input functions for training and evaluation.
def train_input_fn():
    datasets = tfds.load(name='mnist', )
    mnist_train = datasets['train']

    dataset = mnist_train.map(preprocess)
    dataset = dataset.shuffle(BUFFER_SIZE)
    dataset = dataset.batch(BATCH_SIZE)
    return dataset.repeat()

# %%
def eval_input_fn():
    datasets = tfds.load(name='mnist')
    mnist_test = datasets['test']
    dataset = mnist_test.map(preprocess).batch(BATCH_SIZE)
    return dataset

# %%
#no sirve
# Define a feature column.
#image_feature_column = tf.feature_column.numeric_column(key='image-pixels', shape=(28*28)) # Make it as a feature column of 784

# %%
# Crear el modelo usando Keras Sequential como indica la guía
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28, 1)), # Aplanar la imagen
    tf.keras.layers.Dense(32, activation='relu'),     # Primera capa oculta
    tf.keras.layers.Dense(16, activation='relu'),     # Segunda capa oculta
    tf.keras.layers.Dense(10, activation='softmax')   # Capa de salida (10 clases)
])

# Configurar el modelo para el entrenamiento pasando el optimizador y la función de pérdida
model.compile(optimizer='adam', 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])
# Out:
# c:\todo\Anaconda\envs\curso_ia\lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Obtener los datasets
train_dataset = train_input_fn()
eval_dataset = eval_input_fn()

# Entrenar el modelo llamando a Model.fit
print("Iniciando entrenamiento...")
history = model.fit(
    train_dataset,
    epochs=NUM_EPOCHS,
    steps_per_epoch=steps_per_epoch
)

# Evaluar el modelo con Model.evaluate
print("\nIniciando evaluación...")
eval_result = model.evaluate(eval_dataset, return_dict=True)
print(f"Resultado de la evaluación: {eval_result}")
# Out:
# Iniciando entrenamiento...
# Epoch 1/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8720 - loss: 0.4393
# Epoch 2/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9426 - loss: 0.2004
# Epoch 3/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9528 - loss: 0.1595
# Epoch 4/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9588 - loss: 0.1369
# Epoch 5/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9639 - loss: 0.1205
# Epoch 6/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9678 - loss: 0.1085
# Epoch 7/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9701 - loss: 0.1005
# Epoch 8/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9722 - loss: 0.0919
# Epoch 9/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9741 - loss: 0.0860
# Epoch 10/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9756 - loss: 0.0799
# Epoch 11/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9765 - loss: 0.0751
# Epoch 12/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9779 - loss: 0.0719
# Epoch 13/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9797 - loss: 0.0659
# Epoch 14/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9804 - loss: 0.0627
# Epoch 15/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9812 - loss: 0.0587
# Epoch 16/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9824 - loss: 0.0557
# Epoch 17/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9832 - loss: 0.0526
# Epoch 18/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9840 - loss: 0.0504
# Epoch 19/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9849 - loss: 0.0480
# Epoch 20/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9850 - loss: 0.0465
#
# Iniciando evaluación...
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9708 - loss: 0.1138
# Resultado de la evaluación: {'accuracy': 0.97079998254776, 'loss': 0.11376260966062546}
